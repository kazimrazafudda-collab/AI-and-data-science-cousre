# %% [markdown]
# # *Part 1 (_NumPy vs Python Lists_)*

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\skytech computers\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
import time

# %%
python_list = list(range(100000))

# %%
Numpy_array = np.arange(100000)

# %%
start_time = time.time()
python_result = (x * 5 for x in python_list)
end_time = time.time()
python_time = end_time - start_time

# %%
start_time = time.time()
numpy_result = Numpy_array * 5
end_time = time.time()
numpy_time = end_time - start_time

# %%
if numpy_time < python_time:
    print(" NumPy is faster because it performs vectorized operations")
else:
    print(" Python list is faster in this run (rare). Usually, NumPy is faster.")
# Out:
#  NumPy is faster because it performs vectorized operations

# %%
print(f"Time taken by Python list: {python_time:.6f} seconds")
print(f"Time taken by NumPy array: {numpy_time:.6f} seconds")
# Out:
# Time taken by Python list: 0.002611 seconds
# Time taken by NumPy array: 0.000891 seconds
