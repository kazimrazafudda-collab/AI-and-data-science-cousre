# %% [markdown]
# Task 4 (Employee Salary Protection)

# %%
class Employee:
    def __init__(self, name, salary=0):
        # Private attributes
        self.__name = name
        self.__salary = 0
        self.set_salary(salary)  

    # Getter for name
    def get_name(self):
        return self.__name

    # Setter for salary (positive)
    def set_salary(self, salary):
        if salary > 0:
            self.__salary = salary
        else:
            print("Invalid salary! Salary must be positive.")

    # Method to show employee details
    def show_details(self):
        print(f"Employee Name: {self.__name}")
        print(f"Employee Salary: {self.__salary}")

# %%
emp1 = Employee("Farjad", 100000)

# %%
emp1.show_details()
# Out:
# Employee Name: Farjad
# Employee Salary: 100000

# %%
emp1.set_salary(-20000)
# Out:
# Invalid salary! Salary must be positive.

# %%
emp1.set_salary(250000)

# %%
emp1.show_details()
# Out:
# Employee Name: Farjad
# Employee Salary: 250000
