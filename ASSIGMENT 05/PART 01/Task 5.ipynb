# %% [markdown]
# Task 5 (Shopping Cart)

# %%
class ShoppingCart:
    def __init__(self):
           #list to store items
        self.__items = []

    # Add item 
    def add_item(self, item):
        if item not in self.__items:
            self.__items.append(item)
            print(f"{item} added to cart.")
        else:
            print(f"{item} is already in the cart.")

    # Remove item 
    def remove_item(self, item):
        if item in self.__items:
            self.__items.remove(item)
            print(f"{item} removed from cart.")
        else:
            print(f"{item} not found in the cart.")

    # View cart 
    def view_cart(self):
        if self.__items:
            print("Items in your cart:")
            for item in self.__items:
                print(f"- {item}")
        else:
            print("Your cart is empty.")
        return self.__items

# %%
cart = ShoppingCart()

# %%
cart.add_item("Strwberry")
cart.add_item("apple")
cart.add_item("Orange")
cart.add_item("Strwberry")
# Out:
# Strwberry is already in the cart.
# apple is already in the cart.
# Orange is already in the cart.
# Strwberry is already in the cart.

# %%
cart.view_cart()
# Out:
# Items in your cart:
# - Strwberry
# - apple
# - Orange
# ['Strwberry', 'apple', 'Orange']

# %%
cart.remove_item("Orange")
# Out:
# Orange removed from cart.

# %%
cart.view_cart()
# Out:
# Items in your cart:
# - Strwberry
# - apple
# ['Strwberry', 'apple']
